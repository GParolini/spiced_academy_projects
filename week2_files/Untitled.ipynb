# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("data/penguins_simple.csv", sep = ';')

# %%
df
# Out:
#     Species  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0    Adelie                39.1               18.7                181.0
# 1    Adelie                39.5               17.4                186.0
# 2    Adelie                40.3               18.0                195.0
# 3    Adelie                36.7               19.3                193.0
# 4    Adelie                39.3               20.6                190.0
# ..      ...                 ...                ...                  ...
# 328  Gentoo                47.2               13.7                214.0
# 329  Gentoo                46.8               14.3                215.0
# 330  Gentoo                50.4               15.7                222.0
# 331  Gentoo                45.2               14.8                212.0
# 332  Gentoo                49.9               16.1                213.0
#
#      Body Mass (g)     Sex
# 0           3750.0    MALE
# 1           3800.0  FEMALE
# ...

# %%
df['Species'].value_counts()
color=['blue']*146 + ['pink']*119 + ['green']*68
df.plot.scatter(x='Culmen Length (mm)',
                y='Culmen Depth (mm)',
               c= color);

# %%
df.plot.scatter(x='Culmen Length (mm)',
                y='Culmen Depth (mm)',
               c= pd.factorize(df['Species'])[0]);

# %%
sns.scatterplot(data=df, x ='Culmen Length (mm)',
                y='Culmen Depth (mm)',
           hue ='Species');

# %%
df['Species'].value_counts().plot(kind='bar');

# %%
df['Body Mass (g)'].plot(kind='hist', bins = 30);

# %%
df2 = df[df['Species'].isin(['Adelie', 'Gentoo'])]

# %%
df2
# Out:
#     Species  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0    Adelie                39.1               18.7                181.0
# 1    Adelie                39.5               17.4                186.0
# 2    Adelie                40.3               18.0                195.0
# 3    Adelie                36.7               19.3                193.0
# 4    Adelie                39.3               20.6                190.0
# ..      ...                 ...                ...                  ...
# 328  Gentoo                47.2               13.7                214.0
# 329  Gentoo                46.8               14.3                215.0
# 330  Gentoo                50.4               15.7                222.0
# 331  Gentoo                45.2               14.8                212.0
# 332  Gentoo                49.9               16.1                213.0
#
#      Body Mass (g)     Sex
# 0           3750.0    MALE
# 1           3800.0  FEMALE
# ...

# %%
df2['Species'].unique()

# %% [markdown]
# ## Logistic regression
#
# ** Task: predict the penguin species from the beak

# %% [markdown]
# sklearn.model_selection.train_test_split(*arrays, test_size=None, train_size=None, random_state=None, shuffle=True, stratify=None)[source]¶
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html?highlight=train_test_split#sklearn.model_selection.train_test_split

# %% [markdown]
# class sklearn.linear_model.LogisticRegression(penalty='l2', *, dual=False, tol=0.0001, C=1.0, fit_intercept=True, intercept_scaling=1, class_weight=None, random_state=None, solver='lbfgs', max_iter=100, multi_class='auto', verbose=0, warm_start=False, n_jobs=None, l1_ratio=None)¶
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html?highlight=logisticregression()

# %% [markdown]
# sklearn.metrics.accuracy_score(y_true, y_pred, *, normalize=True, sample_weight=None)
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html?highlight=accuracy_score#sklearn.metrics.accuracy_score
